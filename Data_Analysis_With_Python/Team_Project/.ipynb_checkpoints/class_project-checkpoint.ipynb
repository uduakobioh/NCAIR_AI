# %% [markdown]
# # Sales Insight Case Study

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob as glob

# %%
path = './Sales_Data'
filenames = glob.glob(path + "/*.csv")
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# %% [markdown]
# * Combine the data from the 12 months into a single spreadsheet
# * Merges the data sets with pd.concat and ignore the index

# %%
data = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# **Remove data with NaN**
# **Clean up the data**

# %%
features = ['Order Date', 'Product', 'Quantity Ordered', 'Price Each', 'Purchase Address']
features
# Out:
# ['Order Date', 'Product', 'Quantity Ordered', 'Price Each', 'Purchase Address']

# %%
cleanedData = data[features]
cleanedData
# Out:
#             Order Date                 Product Quantity Ordered Price Each  \
# 0       12/30/19 00:01      Macbook Pro Laptop                1       1700
# 1       12/29/19 07:03      LG Washing Machine                1      600.0
# 2       12/12/19 18:21    USB-C Charging Cable                1      11.95
# 3       12/22/19 15:13        27in FHD Monitor                1     149.99
# 4       12/18/19 12:38    USB-C Charging Cable                1      11.95
# ...                ...                     ...              ...        ...
# 186845  06/07/19 19:02  AAA Batteries (4-pack)                1       2.99
# 186846  06/01/19 19:29        27in FHD Monitor                1     149.99
# 186847  06/22/19 18:57    USB-C Charging Cable                1      11.95
# 186848  06/26/19 18:35    USB-C Charging Cable                1      11.95
# 186849  06/25/19 14:33  AAA Batteries (4-pack)                1       2.99
#
#                               Purchase Address
# 0       136 Church St, New York City, NY 10001
# 1          562 2nd St, New York City, NY 10001
# 2         277 Main St, New York City, NY 10001
# 3          410 6th St, San Francisco, CA 94016
# 4                43 Hill St, Atlanta, GA 30301
# ...                                        ...
# 186845           795 Pine St, Boston, MA 02215
# 186846   495 North St, New York City, NY 10001
# 186847   319 Ridge St, San Francisco, CA 94016
# 186848    916 Main St, San Francisco, CA 94016
# 186849          209 11th St, Atlanta, GA 30301
#
# [186850 rows x 5 columns]

# %%
# Drop rows with missing values
cleanedData = cleanedData.dropna(how='all')
# Drop rows that contain 'Order Date, Product, Quantity Ordered, Price Each, Purchase Address'
cleanedData = cleanedData[cleanedData['Order Date'] != 'Order Date']
cleanedData =  cleanedData[cleanedData['Product'] != 'Product']
cleanedData =  cleanedData[cleanedData['Quantity Ordered'] != 'Quantity Ordered']
cleanedData =  cleanedData[cleanedData['Price Each'] != 'Price Each']
cleanedData =  cleanedData[cleanedData['Purchase Address'] != 'Purchase Address']
cleanedData
# Out:
#             Order Date                 Product Quantity Ordered Price Each  \
# 0       12/30/19 00:01      Macbook Pro Laptop                1       1700
# 1       12/29/19 07:03      LG Washing Machine                1      600.0
# 2       12/12/19 18:21    USB-C Charging Cable                1      11.95
# 3       12/22/19 15:13        27in FHD Monitor                1     149.99
# 4       12/18/19 12:38    USB-C Charging Cable                1      11.95
# ...                ...                     ...              ...        ...
# 186845  06/07/19 19:02  AAA Batteries (4-pack)                1       2.99
# 186846  06/01/19 19:29        27in FHD Monitor                1     149.99
# 186847  06/22/19 18:57    USB-C Charging Cable                1      11.95
# 186848  06/26/19 18:35    USB-C Charging Cable                1      11.95
# 186849  06/25/19 14:33  AAA Batteries (4-pack)                1       2.99
#
#                               Purchase Address
# 0       136 Church St, New York City, NY 10001
# 1          562 2nd St, New York City, NY 10001
# 2         277 Main St, New York City, NY 10001
# 3          410 6th St, San Francisco, CA 94016
# 4                43 Hill St, Atlanta, GA 30301
# ...                                        ...
# 186845           795 Pine St, Boston, MA 02215
# 186846   495 North St, New York City, NY 10001
# 186847   319 Ridge St, San Francisco, CA 94016
# 186848    916 Main St, San Francisco, CA 94016
# 186849          209 11th St, Atlanta, GA 30301
#
# [185950 rows x 5 columns]

# %%
cleanedData[cleanedData["Order Date"] == "Order Date"]

# %%
# get month from order date
cleanedData['Month'] = cleanedData['Order Date'].str[0:2]
cleanedData['Month'] = pd.to_numeric(cleanedData['Month'], errors='coerce')
cleanedData['Month'] = cleanedData['Month'].fillna(0).astype(int)
cleanedData
# Out:
#             Order Date                 Product Quantity Ordered Price Each  \
# 0       12/30/19 00:01      Macbook Pro Laptop                1       1700
# 1       12/29/19 07:03      LG Washing Machine                1      600.0
# 2       12/12/19 18:21    USB-C Charging Cable                1      11.95
# 3       12/22/19 15:13        27in FHD Monitor                1     149.99
# 4       12/18/19 12:38    USB-C Charging Cable                1      11.95
# ...                ...                     ...              ...        ...
# 186845  06/07/19 19:02  AAA Batteries (4-pack)                1       2.99
# 186846  06/01/19 19:29        27in FHD Monitor                1     149.99
# 186847  06/22/19 18:57    USB-C Charging Cable                1      11.95
# 186848  06/26/19 18:35    USB-C Charging Cable                1      11.95
# 186849  06/25/19 14:33  AAA Batteries (4-pack)                1       2.99
#
#                               Purchase Address  Month
# 0       136 Church St, New York City, NY 10001     12
# 1          562 2nd St, New York City, NY 10001     12
# 2         277 Main St, New York City, NY 10001     12
# 3          410 6th St, San Francisco, CA 94016     12
# 4                43 Hill St, Atlanta, GA 30301     12
# ...                                        ...    ...
# 186845           795 Pine St, Boston, MA 02215      6
# 186846   495 North St, New York City, NY 10001      6
# 186847   319 Ridge St, San Francisco, CA 94016      6
# 186848    916 Main St, San Francisco, CA 94016      6
# 186849          209 11th St, Atlanta, GA 30301      6
#
# [185950 rows x 6 columns]

# %% [markdown]
# **Create a function to convert the months into strings**

# %%
# convert month in january to december to int
def convertMonth(month):
    if month == 1:
        return 'January'
    elif month == 2:
        return 'February'
    elif month == 3:
        return 'March'
    elif month == 4:
        return 'April'
    elif month == 5:
        return 'May'
    elif month == 6:
        return 'June'
    elif month == 7:
        return 'July'
    elif month == 8:
        return 'August'
    elif month == 9:
        return 'September'
    elif month == 10:
        return 'October'
    elif month == 11:
        return 'November'
    elif month == 12:
        return 'December'

# %%
cleanedData['Month'] = cleanedData['Month'].apply(convertMonth)
cleanedData
# Out:
#             Order Date                 Product Quantity Ordered Price Each  \
# 0       12/30/19 00:01      Macbook Pro Laptop                1       1700
# 1       12/29/19 07:03      LG Washing Machine                1      600.0
# 2       12/12/19 18:21    USB-C Charging Cable                1      11.95
# 3       12/22/19 15:13        27in FHD Monitor                1     149.99
# 4       12/18/19 12:38    USB-C Charging Cable                1      11.95
# ...                ...                     ...              ...        ...
# 186845  06/07/19 19:02  AAA Batteries (4-pack)                1       2.99
# 186846  06/01/19 19:29        27in FHD Monitor                1     149.99
# 186847  06/22/19 18:57    USB-C Charging Cable                1      11.95
# 186848  06/26/19 18:35    USB-C Charging Cable                1      11.95
# 186849  06/25/19 14:33  AAA Batteries (4-pack)                1       2.99
#
#                               Purchase Address     Month
# 0       136 Church St, New York City, NY 10001  December
# 1          562 2nd St, New York City, NY 10001  December
# 2         277 Main St, New York City, NY 10001  December
# 3          410 6th St, San Francisco, CA 94016  December
# 4                43 Hill St, Atlanta, GA 30301  December
# ...                                        ...       ...
# 186845           795 Pine St, Boston, MA 02215      June
# 186846   495 North St, New York City, NY 10001      June
# 186847   319 Ridge St, San Francisco, CA 94016      June
# 186848    916 Main St, San Francisco, CA 94016      June
# 186849          209 11th St, Atlanta, GA 30301      June
#
# [185950 rows x 6 columns]

# %% [markdown]
# * Convert Quantity Ordered and Price Each to numeric

# %%
# convert quantity ordered and price each to int
cleanedData['Quantity Ordered'] = pd.to_numeric(cleanedData['Quantity Ordered'], errors='coerce').fillna(0).astype(int)
cleanedData['Price Each'] = pd.to_numeric(cleanedData['Price Each'], errors='coerce').fillna(0).astype(int)
cleanedData
# Out:
#             Order Date                 Product  Quantity Ordered  Price Each  \
# 0       12/30/19 00:01      Macbook Pro Laptop                 1        1700
# 1       12/29/19 07:03      LG Washing Machine                 1         600
# 2       12/12/19 18:21    USB-C Charging Cable                 1          11
# 3       12/22/19 15:13        27in FHD Monitor                 1         149
# 4       12/18/19 12:38    USB-C Charging Cable                 1          11
# ...                ...                     ...               ...         ...
# 186845  06/07/19 19:02  AAA Batteries (4-pack)                 1           2
# 186846  06/01/19 19:29        27in FHD Monitor                 1         149
# 186847  06/22/19 18:57    USB-C Charging Cable                 1          11
# 186848  06/26/19 18:35    USB-C Charging Cable                 1          11
# 186849  06/25/19 14:33  AAA Batteries (4-pack)                 1           2
#
#                               Purchase Address     Month
# 0       136 Church St, New York City, NY 10001  December
# 1          562 2nd St, New York City, NY 10001  December
# 2         277 Main St, New York City, NY 10001  December
# 3          410 6th St, San Francisco, CA 94016  December
# 4                43 Hill St, Atlanta, GA 30301  December
# ...                                        ...       ...
# 186845           795 Pine St, Boston, MA 02215      June
# 186846   495 North St, New York City, NY 10001      June
# 186847   319 Ridge St, San Francisco, CA 94016      June
# 186848    916 Main St, San Francisco, CA 94016      June
# 186849          209 11th St, Atlanta, GA 30301      June
#
# [185950 rows x 6 columns]

# %% [markdown]
# * Add Sales to the data set

# %%
# add sales column
cleanedData['Sales'] = cleanedData['Quantity Ordered'] * cleanedData['Price Each']
cleanedData
# Out:
#             Order Date                 Product  Quantity Ordered  Price Each  \
# 0       12/30/19 00:01      Macbook Pro Laptop                 1        1700
# 1       12/29/19 07:03      LG Washing Machine                 1         600
# 2       12/12/19 18:21    USB-C Charging Cable                 1          11
# 3       12/22/19 15:13        27in FHD Monitor                 1         149
# 4       12/18/19 12:38    USB-C Charging Cable                 1          11
# ...                ...                     ...               ...         ...
# 186845  06/07/19 19:02  AAA Batteries (4-pack)                 1           2
# 186846  06/01/19 19:29        27in FHD Monitor                 1         149
# 186847  06/22/19 18:57    USB-C Charging Cable                 1          11
# 186848  06/26/19 18:35    USB-C Charging Cable                 1          11
# 186849  06/25/19 14:33  AAA Batteries (4-pack)                 1           2
#
#                               Purchase Address     Month  Sales
# 0       136 Church St, New York City, NY 10001  December   1700
# 1          562 2nd St, New York City, NY 10001  December    600
# 2         277 Main St, New York City, NY 10001  December     11
# 3          410 6th St, San Francisco, CA 94016  December    149
# 4                43 Hill St, Atlanta, GA 30301  December     11
# ...                                        ...       ...    ...
# 186845           795 Pine St, Boston, MA 02215      June      2
# 186846   495 North St, New York City, NY 10001      June    149
# 186847   319 Ridge St, San Francisco, CA 94016      June     11
# 186848    916 Main St, San Francisco, CA 94016      June     11
# 186849          209 11th St, Atlanta, GA 30301      June      2
#
# [185950 rows x 7 columns]

# %%
# Month with highest sales
cleanedData.groupby('Month').sum()
cleanedData.groupby('Month').sum()
monthWithHighestSales = cleanedData.groupby('Month').sum().sort_values('Quantity Ordered', ascending=False)
# Out:
# /var/folders/z1/g3kc4r891r5dk40w3hq3k4wr0000gn/T/ipykernel_12204/651408764.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cleanedData.groupby('Month').sum()
# /var/folders/z1/g3kc4r891r5dk40w3hq3k4wr0000gn/T/ipykernel_12204/651408764.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cleanedData.groupby('Month').sum()
# /var/folders/z1/g3kc4r891r5dk40w3hq3k4wr0000gn/T/ipykernel_12204/651408764.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   monthWithHighestSales = cleanedData.groupby('Month').sum().sort_values('Quantity Ordered', ascending=False)

# %%
# what was the best month for sales? How much was earned that month?
monthWithHighestSales = monthWithHighestSales.reset_index()
monthWithHighestSales
# Out:
#         Month  Quantity Ordered  Price Each    Sales
# 0    December             28114     4569702  4591824
# 1     October             22703     3700299  3719205
# 2       April             20558     3354065  3374951
# 3    November             19798     3167467  3184394
# 4         May             18667     3122775  3138287
# 5       March             17005     2779903  2794068
# 6        July             16072     2621867  2635443
# 7        June             15253     2551984  2566187
# 8    February             13449     2179934  2191696
# 9      August             13448     2221451  2234194
# 10  September             13109     2076254  2087435
# 11    January             10903     1804577  1813956

# %%
monthWithHighestSales.plot(x='Month', y='Quantity Ordered', kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# # What city sold the most products?

# %%
# What city had the highest number of sales?
# add city column
def getCity(address):
    return address.split(',')[1]

# %%
# add city column
cleanedData['City'] = cleanedData['Purchase Address'].str.split(',').str[1]
cleanedData
# Out:
#             Order Date                 Product  Quantity Ordered  Price Each  \
# 0       12/30/19 00:01      Macbook Pro Laptop                 1        1700
# 1       12/29/19 07:03      LG Washing Machine                 1         600
# 2       12/12/19 18:21    USB-C Charging Cable                 1          11
# 3       12/22/19 15:13        27in FHD Monitor                 1         149
# 4       12/18/19 12:38    USB-C Charging Cable                 1          11
# ...                ...                     ...               ...         ...
# 186845  06/07/19 19:02  AAA Batteries (4-pack)                 1           2
# 186846  06/01/19 19:29        27in FHD Monitor                 1         149
# 186847  06/22/19 18:57    USB-C Charging Cable                 1          11
# 186848  06/26/19 18:35    USB-C Charging Cable                 1          11
# 186849  06/25/19 14:33  AAA Batteries (4-pack)                 1           2
#
#                               Purchase Address     Month  Sales  \
# 0       136 Church St, New York City, NY 10001  December   1700
# 1          562 2nd St, New York City, NY 10001  December    600
# 2         277 Main St, New York City, NY 10001  December     11
# 3          410 6th St, San Francisco, CA 94016  December    149
# 4                43 Hill St, Atlanta, GA 30301  December     11
# ...                                        ...       ...    ...
# 186845           795 Pine St, Boston, MA 02215      June      2
# 186846   495 North St, New York City, NY 10001      June    149
# 186847   319 Ridge St, San Francisco, CA 94016      June     11
# 186848    916 Main St, San Francisco, CA 94016      June     11
# 186849          209 11th St, Atlanta, GA 30301      June      2
#
#                   City
# 0        New York City
# 1        New York City
# 2        New York City
# 3        San Francisco
# 4              Atlanta
# ...                ...
# 186845          Boston
# 186846   New York City
# 186847   San Francisco
# 186848   San Francisco
# 186849         Atlanta
#
# [185950 rows x 8 columns]

# %%
# get city with highest sales
cityWithHighestSales = cleanedData.groupby('City').sum().sort_values('Quantity Ordered', ascending=False)
cityWithHighestSales
# Out:
# /var/folders/z1/g3kc4r891r5dk40w3hq3k4wr0000gn/T/ipykernel_12204/1928903852.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cityWithHighestSales = cleanedData.groupby('City').sum().sort_values('Quantity Ordered', ascending=False)
#                 Quantity Ordered  Price Each    Sales
# City
#  San Francisco             50239     8178055  8223669
#  Los Angeles               33289     5399261  5426973
#  New York City             27932     4616764  4642872
#  Boston                    22528     3622510  3644327
#  Dallas                    16730     2741555  2755117
#  Atlanta                   16602     2768857  2782841
#  Seattle                   16553     2722310  2735070
#  Portland                  14053     2298450  2309717
#  Austin                    11153     1802516  1811054

# %%
cityWithHighestSales.sort_values('Quantity Ordered', ascending=False)
# Out:
#                 Quantity Ordered  Price Each    Sales
# City
#  San Francisco             50239     8178055  8223669
#  Los Angeles               33289     5399261  5426973
#  New York City             27932     4616764  4642872
#  Boston                    22528     3622510  3644327
#  Dallas                    16730     2741555  2755117
#  Atlanta                   16602     2768857  2782841
#  Seattle                   16553     2722310  2735070
#  Portland                  14053     2298450  2309717
#  Austin                    11153     1802516  1811054

# %%
cityWithHighestSales = cityWithHighestSales.reset_index()
cityWithHighestSales.plot(x='City', y='Quantity Ordered', kind='bar')
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# # What time should we display advertisemens to maximize the likelihood of customer’s buying a product?

# %%
# add hour column
cleanedData['Hour'] = cleanedData['Order Date'].str.split(' ').str[1].str.split(':').str[0]
cleanedData
# Out:
#             Order Date                 Product  Quantity Ordered  Price Each  \
# 0       12/30/19 00:01      Macbook Pro Laptop                 1        1700
# 1       12/29/19 07:03      LG Washing Machine                 1         600
# 2       12/12/19 18:21    USB-C Charging Cable                 1          11
# 3       12/22/19 15:13        27in FHD Monitor                 1         149
# 4       12/18/19 12:38    USB-C Charging Cable                 1          11
# ...                ...                     ...               ...         ...
# 186845  06/07/19 19:02  AAA Batteries (4-pack)                 1           2
# 186846  06/01/19 19:29        27in FHD Monitor                 1         149
# 186847  06/22/19 18:57    USB-C Charging Cable                 1          11
# 186848  06/26/19 18:35    USB-C Charging Cable                 1          11
# 186849  06/25/19 14:33  AAA Batteries (4-pack)                 1           2
#
#                               Purchase Address     Month  Sales  \
# 0       136 Church St, New York City, NY 10001  December   1700
# 1          562 2nd St, New York City, NY 10001  December    600
# 2         277 Main St, New York City, NY 10001  December     11
# 3          410 6th St, San Francisco, CA 94016  December    149
# 4                43 Hill St, Atlanta, GA 30301  December     11
# ...                                        ...       ...    ...
# 186845           795 Pine St, Boston, MA 02215      June      2
# 186846   495 North St, New York City, NY 10001      June    149
# 186847   319 Ridge St, San Francisco, CA 94016      June     11
# 186848    916 Main St, San Francisco, CA 94016      June     11
# 186849          209 11th St, Atlanta, GA 30301      June      2
#
#                   City Hour
# 0        New York City   00
# 1        New York City   07
# 2        New York City   18
# 3        San Francisco   15
# 4              Atlanta   12
# ...                ...  ...
# 186845          Boston   19
# 186846   New York City   19
# 186847   San Francisco   18
# 186848   San Francisco   18
# 186849         Atlanta   14
#
# [185950 rows x 9 columns]

# %%
# group by hour
hourWithHighestSales = cleanedData.groupby('Hour').sum().sort_values('Quantity Ordered', ascending=False)
hourWithHighestSales
# Out:
# /var/folders/z1/g3kc4r891r5dk40w3hq3k4wr0000gn/T/ipykernel_12204/681670055.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   hourWithHighestSales = cleanedData.groupby('Hour').sum().sort_values('Quantity Ordered', ascending=False)
#       Quantity Ordered  Price Each    Sales
# Hour
# 19               14470     2388956  2401834
# 12               14202     2290511  2305962
# 11               14005     2279609  2289873
# 18               13802     2198498  2208735
# 20               13768     2259062  2271164
# 13               13685     2130632  2144832
# 14               12362     2064016  2074206
# 10               12308     1924427  1934780
# 21               12244     2022652  2032659
# 17               12229     2108604  2119953
# 16               11662     1884688  1895646
# 15               11391     1923599  1932843
# 22                9899     1592854  1599938
# 09                9816     1621987  1631520
# 23                7065     1167910  1173852
# 08                7002     1181335  1187019
# 07                4556      737574   741353
# 00                4428      706387   710325
# 06                2810      443148   445957
# 01                2619      456769   458894
# 05                1493      228631   229529
# 02                1398      232908   233780
# 04                 937      161432   161956
# 03                 928      144089   145030

# %%
# get element by index
hourWithHighestSales.iloc[0]
# Out:
# Quantity Ordered      14470
# Price Each          2388956
# Sales               2401834
# Name: 19, dtype: int64

# %%
# plot hour with highest sales
hourWithHighestSales = hourWithHighestSales.reset_index()
hourWithHighestSales.plot(x='Hour', y='Quantity Ordered', kind='bar')
# Out:
# <Axes: xlabel='Hour'>

# %% [markdown]
# # What products are most often sold together?

# %%
new_data = data[['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date', 'Purchase Address']]

# %%
# What products are most often sold together?
# get all orders with same order id
new_data.groupby('Order ID',as_index=False, sort=False).sum()
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 178433   222905  AAA Batteries (4-pack)                1       2.99
# 178434   222906        27in FHD Monitor                1     149.99
# 178435   222907    USB-C Charging Cable                1      11.95
# 178436   222908    USB-C Charging Cable                1      11.95
# 178437   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001
# 1       12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2       12/12/19 18:21    277 Main St, New York City, NY 10001
# 3       12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4       12/18/19 12:38           43 Hill St, Atlanta, GA 30301
# ...                ...                                     ...
# 178433  06/07/19 19:02           795 Pine St, Boston, MA 02215
# 178434  06/01/19 19:29   495 North St, New York City, NY 10001
# 178435  06/22/19 18:57   319 Ridge St, San Francisco, CA 94016
# 178436  06/26/19 18:35    916 Main St, San Francisco, CA 94016
# 178437  06/25/19 14:33          209 11th St, Atlanta, GA 30301
#
# [178438 rows x 6 columns]

# %%
# if order id is duplicated, get product
get_duplicated = new_data[new_data.duplicated(subset=['Order ID'], keep=False)]
get_duplicated
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 16       295681                Google Phone                1        600
# 17       295681        USB-C Charging Cable                1      11.95
# 18       295681  Bose SoundSport Headphones                1      99.99
# 19       295681            Wired Headphones                1      11.99
# 36       295698             Vareebadd Phone                1        400
# ...         ...                         ...              ...        ...
# 186820   222882       AA Batteries (4-pack)                1       3.84
# 186822   222884                Google Phone                1        600
# 186823   222884        USB-C Charging Cable                1      11.95
# 186842   222903                      iPhone                1        700
# 186843   222903    Lightning Charging Cable                1      14.95
#
#             Order Date                         Purchase Address
# 16      12/25/19 12:37              79 Elm St, Boston, MA 02215
# 17      12/25/19 12:37              79 Elm St, Boston, MA 02215
# 18      12/25/19 12:37              79 Elm St, Boston, MA 02215
# 19      12/25/19 12:37              79 Elm St, Boston, MA 02215
# 36      12/13/19 14:32      175 1st St, New York City, NY 10001
# ...                ...                                      ...
# 186820  06/18/19 11:37     990 Walnut St, Los Angeles, CA 90001
# 186822  06/04/19 12:06     819 Pine St, New York City, NY 10001
# 186823  06/04/19 12:06     819 Pine St, New York City, NY 10001
# 186842  06/07/19 22:21  685 Hickory St, New York City, NY 10001
# 186843  06/07/19 22:21  685 Hickory St, New York City, NY 10001
#
# [15549 rows x 6 columns]

# %%
#  what products are most often sold together?
get_duplicated['Grouped'] = get_duplicated.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
get_duplicated
# Out:
# /var/folders/z1/g3kc4r891r5dk40w3hq3k4wr0000gn/T/ipykernel_12204/2454583647.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   get_duplicated['Grouped'] = get_duplicated.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#        Order ID                     Product Quantity Ordered Price Each  \
# 16       295681                Google Phone                1        600
# 17       295681        USB-C Charging Cable                1      11.95
# 18       295681  Bose SoundSport Headphones                1      99.99
# 19       295681            Wired Headphones                1      11.99
# 36       295698             Vareebadd Phone                1        400
# ...         ...                         ...              ...        ...
# 186820   222882       AA Batteries (4-pack)                1       3.84
# 186822   222884                Google Phone                1        600
# 186823   222884        USB-C Charging Cable                1      11.95
# 186842   222903                      iPhone                1        700
# 186843   222903    Lightning Charging Cable                1      14.95
#
#             Order Date                         Purchase Address  \
# 16      12/25/19 12:37              79 Elm St, Boston, MA 02215
# 17      12/25/19 12:37              79 Elm St, Boston, MA 02215
# 18      12/25/19 12:37              79 Elm St, Boston, MA 02215
# 19      12/25/19 12:37              79 Elm St, Boston, MA 02215
# 36      12/13/19 14:32      175 1st St, New York City, NY 10001
# ...                ...                                      ...
# 186820  06/18/19 11:37     990 Walnut St, Los Angeles, CA 90001
# 186822  06/04/19 12:06     819 Pine St, New York City, NY 10001
# 186823  06/04/19 12:06     819 Pine St, New York City, NY 10001
# 186842  06/07/19 22:21  685 Hickory St, New York City, NY 10001
# 186843  06/07/19 22:21  685 Hickory St, New York City, NY 10001
#
#                                                   Grouped
# 16      Google Phone,USB-C Charging Cable,Bose SoundSp...
# 17      Google Phone,USB-C Charging Cable,Bose SoundSp...
# 18      Google Phone,USB-C Charging Cable,Bose SoundSp...
# 19      Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36                   Vareebadd Phone,USB-C Charging Cable
# ...                                                   ...
# 186820     Apple Airpods Headphones,AA Batteries (4-pack)
# 186822                  Google Phone,USB-C Charging Cable
# 186823                  Google Phone,USB-C Charging Cable
# 186842                    iPhone,Lightning Charging Cable
# 186843                    iPhone,Lightning Charging Cable
#
# [15549 rows x 7 columns]

# %%
# drop non duplicated rows
get_duplicated = get_duplicated[['Order ID', 'Grouped']].drop_duplicates()
get_duplicated
# Out:
#        Order ID                                            Grouped
# 16       295681  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36       295698               Vareebadd Phone,USB-C Charging Cable
# 42       295703   AA Batteries (4-pack),Bose SoundSport Headphones
# 66       295726                    iPhone,Lightning Charging Cable
# 76       295735   iPhone,Apple Airpods Headphones,Wired Headphones
# ...         ...                                                ...
# 186798   222863        27in FHD Monitor,Bose SoundSport Headphones
# 186804   222868                    iPhone,Apple Airpods Headphones
# 186819   222882     Apple Airpods Headphones,AA Batteries (4-pack)
# 186822   222884                  Google Phone,USB-C Charging Cable
# 186842   222903                    iPhone,Lightning Charging Cable
#
# [7138 rows x 2 columns]

# %%
# most often sold together
most_sold_together = get_duplicated.groupby('Grouped').count()
most_sold_together
# Out:
#                                                   Order ID
# Grouped
# 20in Monitor,20in Monitor                                3
# 20in Monitor,27in FHD Monitor                            2
# 20in Monitor,34in Ultrawide Monitor                      1
# 20in Monitor,AA Batteries (4-pack)                       6
# 20in Monitor,AAA Batteries (4-pack)                      3
# ...                                                    ...
# iPhone,USB-C Charging Cable                             12
# iPhone,Vareebadd Phone                                   3
# iPhone,Wired Headphones                                361
# iPhone,Wired Headphones,Lightning Charging Cable         1
# iPhone,iPhone                                            1
#
# [367 rows x 1 columns]

# %%
most_sold_together.sort_values('Order ID', ascending=False)
monthWithHighestSales = monthWithHighestSales.reset_index()
monthWithHighestSales
# Out:
#     index      Month  Quantity Ordered  Price Each    Sales
# 0       0   December             28114     4569702  4591824
# 1       1    October             22703     3700299  3719205
# 2       2      April             20558     3354065  3374951
# 3       3   November             19798     3167467  3184394
# 4       4        May             18667     3122775  3138287
# 5       5      March             17005     2779903  2794068
# 6       6       July             16072     2621867  2635443
# 7       7       June             15253     2551984  2566187
# 8       8   February             13449     2179934  2191696
# 9       9     August             13448     2221451  2234194
# 10     10  September             13109     2076254  2087435
# 11     11    January             10903     1804577  1813956

# %% [markdown]
# # What product sold the most? Why do you think it sold the most?

# %%
# What product sold the most? Why do you think it sold the most?
# get product with highest sales
productWithHighestSales = cleanedData.groupby('Product').sum().sort_values('Sales', ascending=False)
productWithHighestSales
# Out:
# /var/folders/z1/g3kc4r891r5dk40w3hq3k4wr0000gn/T/ipykernel_12204/628136907.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   productWithHighestSales = cleanedData.groupby('Product').sum().sort_values('Sales', ascending=False)
#                             Quantity Ordered  Price Each    Sales
# Product
# Macbook Pro Laptop                      4728     8030800  8037600
# iPhone                                  6849     4789400  4794300
# ThinkPad Laptop                         4130     4123872  4125870
# Google Phone                            5532     3315000  3319200
# 27in 4K Gaming Monitor                  6244     2423470  2428916
# 34in Ultrawide Monitor                  6199     2342599  2349421
# Apple Airpods Headphones               15661     2332350  2349150
# Flatscreen TV                           4819     1440000  1445700
# Bose SoundSport Headphones             13457     1319175  1332243
# 27in FHD Monitor                        7550     1118543  1124950
# Vareebadd Phone                         2068      826000   827200
# 20in Monitor                            4129      447009   450061
# LG Washing Machine                       666      399600   399600
# LG Dryer                                 646      387600   387600
# Lightning Charging Cable               23217      303212   325038
# USB-C Charging Cable                   23975      240933   263725
# Wired Headphones                       20557      207702   226127
# AA Batteries (4-pack)                  27635       61731    82905
# AAA Batteries (4-pack)                 31017       41282    62034

# %%
productWithHighestSales.sort_values('Quantity Ordered', ascending=False)
# Out:
#                             Quantity Ordered  Price Each    Sales
# Product
# AAA Batteries (4-pack)                 31017       41282    62034
# AA Batteries (4-pack)                  27635       61731    82905
# USB-C Charging Cable                   23975      240933   263725
# Lightning Charging Cable               23217      303212   325038
# Wired Headphones                       20557      207702   226127
# Apple Airpods Headphones               15661     2332350  2349150
# Bose SoundSport Headphones             13457     1319175  1332243
# 27in FHD Monitor                        7550     1118543  1124950
# iPhone                                  6849     4789400  4794300
# 27in 4K Gaming Monitor                  6244     2423470  2428916
# 34in Ultrawide Monitor                  6199     2342599  2349421
# Google Phone                            5532     3315000  3319200
# Flatscreen TV                           4819     1440000  1445700
# Macbook Pro Laptop                      4728     8030800  8037600
# ThinkPad Laptop                         4130     4123872  4125870
# 20in Monitor                            4129      447009   450061
# Vareebadd Phone                         2068      826000   827200
# LG Washing Machine                       666      399600   399600
# LG Dryer                                 646      387600   387600

# %%
# plot product with highest sales
productWithHighestSales = productWithHighestSales.reset_index()
productWithHighestSales.plot(x='Product', y='Quantity Ordered', kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
# download csv
cleanedData.to_csv('cleanedData.csv')
