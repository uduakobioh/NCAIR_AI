# %% [markdown]
# Import libraries

# %%
import pandas as pd
#import matplotlib as mpl

# %%
data = pd.read_csv(r"C:\\Users\USER\Documents\NITDA_AI_Class-main\JET_CSV_DATA\JET_DATA_1.csv", low_memory=False)
data.head()
# Out:
#    DTT_ID      GL account     Business Unit    Journal    VERS    LDG_NAME  \
# 0  610884  GL account 197  Business Unit 51  Journal 1  VERS 2  LDG_NAME 1
# 1  610885  GL account 197  Business Unit 51  Journal 1  VERS 2  LDG_NAME 1
# 2  610886  GL account 197  Business Unit 51  Journal 1  VERS 2  LDG_NAME 1
# 3  610887  GL account 197  Business Unit 51  Journal 1  VERS 2  LDG_NAME 1
# 4  610888  GL account 197  Business Unit 51  Journal 1  VERS 2  LDG_NAME 1
#
#          Account No    Period  Sequence No   Post Date  ...         DOC_XREF  \
# 0  Account No 28386  Period 4          673  26/10/2014  ...  DOC_XREF 747231
# 1  Account No 28386  Period 4          674  26/10/2014  ...  DOC_XREF 747231
# 2  Account No 28386  Period 4          675  26/10/2014  ...  DOC_XREF 747231
# 3  Account No 28386  Period 4          676  26/10/2014  ...  DOC_XREF 747231
# 4  Account No 28386  Period 4          677  26/10/2014  ...  DOC_XREF 747232
#
#    USER_FLD1     BAT_CRUSER    BAT_CRTERM    SOURCE_ID Source_Date  \
# 0        NaN  BAT_CRUSER 60  BAT_CRTERM 5  SOURCE_ID 4  25/10/2014
# 1        NaN  BAT_CRUSER 60  BAT_CRTERM 5  SOURCE_ID 4  25/10/2014
# 2        NaN  BAT_CRUSER 60  BAT_CRTERM 5  SOURCE_ID 4  25/10/2014
# 3        NaN  BAT_CRUSER 60  BAT_CRTERM 5  SOURCE_ID 4  25/10/2014
# 4        NaN  BAT_CRUSER 60  BAT_CRTERM 5  SOURCE_ID 7  26/10/2014
#
#    SOURCE_TIMEI     SOURCE_USER     POST_USER  \
# 0        221825  SOURCE_USER 61  POST_USER 60
# 1        221825  SOURCE_USER 61  POST_USER 60
# 2        221825  SOURCE_USER 61  POST_USER 60
# 3        221825  SOURCE_USER 61  POST_USER 60
# 4         71424  SOURCE_USER 61  POST_USER 60
#
#                       DOC_UNIQUE_ID
# 0  52bbf5b1e3d94b41a2fe164cf95281ad
# 1  52bbf5b1e3d94b41a2fe164cf95281ad
# 2  52bbf5b1e3d94b41a2fe164cf95281ad
# 3  52bbf5b1e3d94b41a2fe164cf95281ad
# 4                               NaN
#
# [5 rows x 31 columns]

# %%
features = ["GL account", "Journal", "Account No", "BAT_NAME", "JNL_LNE", "Period", "SOURCE_USER", "POST_USER", "Amount"]
data = data[features]
